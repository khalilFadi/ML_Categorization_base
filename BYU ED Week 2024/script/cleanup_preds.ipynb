# %%
import pandas as pd 
df = pd.read_csv('preds.csv')
df_cleaned = df.dropna(subset=['text']).replace('', pd.NA).dropna(subset=['text'])
df_cleaned.to_csv('preds.csv')

# %%
df_cleaned.head(10)
# Out:
#     Unnamed: 0.1  Unnamed: 0            StartDate              EndDate  \
# 0              0           0  2024-08-26 09:22:58  2024-08-26 09:24:26
# 2              2           2  2024-08-26 09:22:12  2024-08-26 09:24:52
# 4              4           4  2024-08-26 09:21:53  2024-08-26 09:26:11
# 5              5           5  2024-08-26 09:24:21  2024-08-26 09:27:08
# 6              6           6  2024-08-26 09:23:39  2024-08-26 09:28:04
# 7              7           7  2024-08-26 09:24:32  2024-08-26 09:28:06
# 8              8           8  2024-08-26 09:21:41  2024-08-26 09:28:36
# 9              9           9  2024-08-26 09:23:35  2024-08-26 09:28:38
# 10            10          10  2024-08-26 09:26:13  2024-08-26 09:28:52
# 11            11          11  2024-08-26 09:25:24  2024-08-26 09:29:17
#
#         Status        IPAddress  Progress  Duration (in seconds)  Finished  \
# 0   IP Address      73.20.43.12       100                     88      True
# ...

# %%
negative_emotions = df[df['emotion'] == 'negative']
negative_emotions['text'][:30]
# Out:
# 4     Brown route shuttles from the Marriott! The ov...
# 5                                    Make it less woke.
# 9     I was very disappointed by the political comme...
# 10    If the description more closely matches the co...
# 12    There was no overflow classroom in the confere...
# 13    Please consider some additional food trucks by...
# 17    A 2-3 class option. I went from 3-5:30 and had...
# 19    More classes on doctrine and easier access.  C...
# 22    A map on rooms in the Wilkinson Center and whi...
# 26    a little more time between classes to get cros...
# 28    Some classes were much too popular for the fac...
# 30                               Nothing to recommend.
# 32    It was great. However the concert in the eveni...
# 35    less people... maybe you should have it twice ...
# 39                                     Smaller classes
# 42           Less walking to the various presentations!
# 45    Food choices Temporal Preparedness class Ed we...
# ...
